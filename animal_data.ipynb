# %% [markdown]
# # Animal dataset - Data Cleaning + EDA!

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('data/Animal Dataset.csv') # import csv from data input

# %%
df.shape # getting the count of rows and columns in the dataframe
# Out:
# (205, 16)

# %%
# checking the data 
df.head(10).style.set_properties(**{'background-color': 'yellow',
                           'color': 'black'})
# Out:
# <style type="text/css">
# #T_669af_row0_col0, #T_669af_row0_col1, #T_669af_row0_col2, #T_669af_row0_col3, #T_669af_row0_col4, #T_669af_row0_col5, #T_669af_row0_col6, #T_669af_row0_col7, #T_669af_row0_col8, #T_669af_row0_col9, #T_669af_row0_col10, #T_669af_row0_col11, #T_669af_row0_col12, #T_669af_row0_col13, #T_669af_row0_col14, #T_669af_row0_col15, #T_669af_row1_col0, #T_669af_row1_col1, #T_669af_row1_col2, #T_669af_row1_col3, #T_669af_row1_col4, #T_669af_row1_col5, #T_669af_row1_col6, #T_669af_row1_col7, #T_669af_row1_col8, #T_669af_row1_col9, #T_669af_row1_col10, #T_669af_row1_col11, #T_669af_row1_col12, #T_669af_row1_col13, #T_669af_row1_col14, #T_669af_row1_col15, #T_669af_row2_col0, #T_669af_row2_col1, #T_669af_row2_col2, #T_669af_row2_col3, #T_669af_row2_col4, #T_669af_row2_col5, #T_669af_row2_col6, #T_669af_row2_col7, #T_669af_row2_col8, #T_669af_row2_col9, #T_669af_row2_col10, #T_669af_row2_col11, #T_669af_row2_col12, #T_669af_row2_col13, #T_669af_row2_col14, #T_669af_row2_col15, #T_669af_row3_col0, #T_669af_row3_col1, #T_669af_row3_col2, #T_669af_row3_col3, #T_669af_row3_col4, #T_669af_row3_col5, #T_669af_row3_col6, #T_669af_row3_col7, #T_669af_row3_col8, #T_669af_row3_col9, #T_669af_row3_col10, #T_669af_row3_col11, #T_669af_row3_col12, #T_669af_row3_col13, #T_669af_row3_col14, #T_669af_row3_col15, #T_669af_row4_col0, #T_669af_row4_col1, #T_669af_row4_col2, #T_669af_row4_col3, #T_669af_row4_col4, #T_669af_row4_col5, #T_669af_row4_col6, #T_669af_row4_col7, #T_669af_row4_col8, #T_669af_row4_col9, #T_669af_row4_col10, #T_669af_row4_col11, #T_669af_row4_col12, #T_669af_row4_col13, #T_669af_row4_col14, #T_669af_row4_col15, #T_669af_row5_col0, #T_669af_row5_col1, #T_669af_row5_col2, #T_669af_row5_col3, #T_669af_row5_col4, #T_669af_row5_col5, #T_669af_row5_col6, #T_669af_row5_col7, #T_669af_row5_col8, #T_669af_row5_col9, #T_669af_row5_col10, #T_669af_row5_col11, #T_669af_row5_col12, #T_669af_row5_col13, #T_669af_row5_col14, #T_669af_row5_col15, #T_669af_row6_col0, #T_669af_row6_col1, #T_669af_row6_col2, #T_669af_row6_col3, #T_669af_row6_col4, #T_669af_row6_col5, #T_669af_row6_col6, #T_669af_row6_col7, #T_669af_row6_col8, #T_669af_row6_col9, #T_669af_row6_col10, #T_669af_row6_col11, #T_669af_row6_col12, #T_669af_row6_col13, #T_669af_row6_col14, #T_669af_row6_col15, #T_669af_row7_col0, #T_669af_row7_col1, #T_669af_row7_col2, #T_669af_row7_col3, #T_669af_row7_col4, #T_669af_row7_col5, #T_669af_row7_col6, #T_669af_row7_col7, #T_669af_row7_col8, #T_669af_row7_col9, #T_669af_row7_col10, #T_669af_row7_col11, #T_669af_row7_col12, #T_669af_row7_col13, #T_669af_row7_col14, #T_669af_row7_col15, #T_669af_row8_col0, #T_669af_row8_col1, #T_669af_row8_col2, #T_669af_row8_col3, #T_669af_row8_col4, #T_669af_row8_col5, #T_669af_row8_col6, #T_669af_row8_col7, #T_669af_row8_col8, #T_669af_row8_col9, #T_669af_row8_col10, #T_669af_row8_col11, #T_669af_row8_col12, #T_669af_row8_col13, #T_669af_row8_col14, #T_669af_row8_col15, #T_669af_row9_col0, #T_669af_row9_col1, #T_669af_row9_col2, #T_669af_row9_col3, #T_669af_row9_col4, #T_669af_row9_col5, #T_669af_row9_col6, #T_669af_row9_col7, #T_669af_row9_col8, #T_669af_row9_col9, #T_669af_row9_col10, #T_669af_row9_col11, #T_669af_row9_col12, #T_669af_row9_col13, #T_669af_row9_col14, #T_669af_row9_col15 {
#   background-color: yellow;
#   color: black;
# }
# </style>
# <table id="T_669af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_669af_level0_col0" class="col_heading level0 col0" >Animal</th>
#       <th id="T_669af_level0_col1" class="col_heading level0 col1" >Height (cm)</th>
#       <th id="T_669af_level0_col2" class="col_heading level0 col2" >Weight (kg)</th>
#       <th id="T_669af_level0_col3" class="col_heading level0 col3" >Color</th>
#       <th id="T_669af_level0_col4" class="col_heading level0 col4" >Lifespan (years)</th>
#       <th id="T_669af_level0_col5" class="col_heading level0 col5" >Diet</th>
#       <th id="T_669af_level0_col6" class="col_heading level0 col6" >Habitat</th>
#       <th id="T_669af_level0_col7" class="col_heading level0 col7" >Predators</th>
#       <th id="T_669af_level0_col8" class="col_heading level0 col8" >Average Speed (km/h)</th>
#       <th id="T_669af_level0_col9" class="col_heading level0 col9" >Countries Found</th>
#       <th id="T_669af_level0_col10" class="col_heading level0 col10" >Conservation Status</th>
#       <th id="T_669af_level0_col11" class="col_heading level0 col11" >Family</th>
#       <th id="T_669af_level0_col12" class="col_heading level0 col12" >Gestation Period (days)</th>
#       <th id="T_669af_level0_col13" class="col_heading level0 col13" >Top Speed (km/h)</th>
#       <th id="T_669af_level0_col14" class="col_heading level0 col14" >Social Structure</th>
#       <th id="T_669af_level0_col15" class="col_heading level0 col15" >Offspring per Birth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_669af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_669af_row0_col0" class="data row0 col0" >Aardvark</td>
#       <td id="T_669af_row0_col1" class="data row0 col1" >105-130</td>
#       <td id="T_669af_row0_col2" class="data row0 col2" >40-65</td>
#       <td id="T_669af_row0_col3" class="data row0 col3" >Grey</td>
#       <td id="T_669af_row0_col4" class="data row0 col4" >20-30</td>
#       <td id="T_669af_row0_col5" class="data row0 col5" >Insectivore</td>
#       <td id="T_669af_row0_col6" class="data row0 col6" >Savannas, Grasslands</td>
#       <td id="T_669af_row0_col7" class="data row0 col7" >Lions, Hyenas</td>
#       <td id="T_669af_row0_col8" class="data row0 col8" >40</td>
#       <td id="T_669af_row0_col9" class="data row0 col9" >Africa</td>
#       <td id="T_669af_row0_col10" class="data row0 col10" >Least Concern</td>
#       <td id="T_669af_row0_col11" class="data row0 col11" >Orycteropodidae</td>
#       <td id="T_669af_row0_col12" class="data row0 col12" >210-240</td>
#       <td id="T_669af_row0_col13" class="data row0 col13" >40</td>
#       <td id="T_669af_row0_col14" class="data row0 col14" >Solitary</td>
#       <td id="T_669af_row0_col15" class="data row0 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_669af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_669af_row1_col0" class="data row1 col0" >Aardwolf</td>
#       <td id="T_669af_row1_col1" class="data row1 col1" >40-50</td>
#       <td id="T_669af_row1_col2" class="data row1 col2" >8-14</td>
#       <td id="T_669af_row1_col3" class="data row1 col3" >Yellow-brown</td>
#       <td id="T_669af_row1_col4" class="data row1 col4" >10-12</td>
#       <td id="T_669af_row1_col5" class="data row1 col5" >Insectivore</td>
#       <td id="T_669af_row1_col6" class="data row1 col6" >Grasslands, Savannas</td>
#       <td id="T_669af_row1_col7" class="data row1 col7" >Lions, Leopards</td>
#       <td id="T_669af_row1_col8" class="data row1 col8" >24-30</td>
#       <td id="T_669af_row1_col9" class="data row1 col9" >Eastern and Southern Africa</td>
#       <td id="T_669af_row1_col10" class="data row1 col10" >Least Concern</td>
#       <td id="T_669af_row1_col11" class="data row1 col11" >Hyaenidae</td>
#       <td id="T_669af_row1_col12" class="data row1 col12" >90</td>
#       <td id="T_669af_row1_col13" class="data row1 col13" >40</td>
#       <td id="T_669af_row1_col14" class="data row1 col14" >Solitary</td>
#       <td id="T_669af_row1_col15" class="data row1 col15" >2-5</td>
#     </tr>
#     <tr>
#       <th id="T_669af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_669af_row2_col0" class="data row2 col0" >African Elephant</td>
#       <td id="T_669af_row2_col1" class="data row2 col1" >270-310</td>
#       <td id="T_669af_row2_col2" class="data row2 col2" >2700-6000</td>
#       <td id="T_669af_row2_col3" class="data row2 col3" >Grey</td>
#       <td id="T_669af_row2_col4" class="data row2 col4" >60-70</td>
#       <td id="T_669af_row2_col5" class="data row2 col5" >Herbivore</td>
#       <td id="T_669af_row2_col6" class="data row2 col6" >Savannah, Forest</td>
#       <td id="T_669af_row2_col7" class="data row2 c

# %%
pd.DataFrame(df.columns,columns=['column name']) # list of columns
# Out:
#                 column name
# 0                    Animal
# 1               Height (cm)
# 2               Weight (kg)
# 3                     Color
# 4          Lifespan (years)
# 5                      Diet
# 6                   Habitat
# 7                 Predators
# 8      Average Speed (km/h)
# 9           Countries Found
# 10      Conservation Status
# 11                   Family
# 12  Gestation Period (days)
# 13         Top Speed (km/h)
# 14         Social Structure
# 15      Offspring per Birth

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Animal                   205 non-null    object
#  1   Height (cm)              205 non-null    object
#  2   Weight (kg)              205 non-null    object
#  3   Color                    205 non-null    object
#  4   Lifespan (years)         205 non-null    object
#  5   Diet                     205 non-null    object
#  6   Habitat                  205 non-null    object
#  7   Predators                205 non-null    object
#  8   Average Speed (km/h)     205 non-null    object
#  9   Countries Found          205 non-null    object
#  10  Conservation Status      205 non-null    object
#  11  Family                   205 non-null    object
#  12  Gestation Period (days)  205 non-null    object
#  13  Top Speed (km/h)         205 non-null    object
#  14  Social Structure         205 non-null    object
#  15  Offspring per Birth      205 non-null    object
# dtypes: object(16)
# memory usage: 25.8+ KB

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# ### As we can see in the data numerci columns have '-' in between values we can replace such values with mean of the left and right values of the '-'.

# %%
df.columns
# Out:
# Index(['Animal', 'Height (cm)', 'Weight (kg)', 'Color', 'Lifespan (years)',
#        'Diet', 'Habitat', 'Predators', 'Average Speed (km/h)',
#        'Countries Found', 'Conservation Status', 'Family',
#        'Gestation Period (days)', 'Top Speed (km/h)', 'Social Structure',
#        'Offspring per Birth'],
#       dtype='object')

# %%
df
# Out:
#                   Animal Height (cm) Weight (kg)             Color  \
# 0               Aardvark     105-130       40-65              Grey
# 1               Aardwolf       40-50        8-14      Yellow-brown
# 2       African Elephant     270-310   2700-6000              Grey
# 3           African Lion      80-110     120-250               Tan
# 4       African Wild Dog       75-80       18-36      Multicolored
# ..                   ...         ...         ...               ...
# 200                  Yak     140-160    500-1200      Brown, Black
# 201  Yellow-Eyed Penguin       60-65         1-3     Yellow, White
# 202            Yeti Crab    Up to 15   Up to 0.5      White, Hairy
# 203                Zebra     220-340     400-900      Black, White
# 204          Zebra Shark   Up to 330    Up to 32  Brown, Yellowish
#
#     Lifespan (years)         Diet               Habitat  \
# 0              20-30  Insectivore  Savannas, Grasslands
# 1              10-12  Insectivore  Grasslands, Savannas
# 2              60-70    Herbivore      Savannah, Forest
# 3              10-14    Carnivore  Grasslands, Savannas
# 4              10-12    Carnivore             Savannahs
# ..               ...          ...                   ...
# 200            20-25    Herbivore             Mountains
# 201         Up to 20    Carnivore         Coastal Areas
# 202         Up to 20     Omnivore    Hydrothermal Vents
# 203            20-25    Herbivore            Grasslands
# 204            25-30    Carnivore           Coral Reefs
#
#                  Predators Average Speed (km/h)              Countries Found  \
# 0            Lions, Hyenas                   40                       Africa
# 1          Lions, Leopards                24-30  Eastern and Southern Africa
# 2            Lions, Hyenas                   25                       Africa
# 3       Hyenas, Crocodiles                   58                       Africa
# 4            Lions, Hyenas                   56           Sub-Saharan Africa
# ..                     ...                  ...                          ...
# 200  Snow Leopards, Wolves                   24      Himalayas, Central Asia
# 201           Seals, Orcas                   25                  New Zealand
# 202         Not Applicable       Not Applicable                Pacific Ocean
# 203          Lions, Hyenas                   25                       Africa
# 204            Larger Fish                   20          Indo-Pacific region
#
#     Conservation Status           Family Gestation Period (days)  \
# 0         Least Concern  Orycteropodidae                 210-240
# 1         Least Concern        Hyaenidae                      90
# 2            Vulnerable     Elephantidae                 640-660
# 3            Vulnerable          Felidae                  98-105
# 4            Endangered          Canidae                      70
# ..                  ...              ...                     ...
# 200       Least Concern          Bovidae                 215-280
# 201          Endangered     Spheniscidae                   80-90
# 202       Not Evaluated         Kiwaidae          Not Applicable
# 203       Least Concern          Equidae                 180-365
# 204          Endangered  Stegostomatidae                   10-25
#
#     Top Speed (km/h) Social Structure Offspring per Birth
# 0                 40         Solitary                   1
# 1                 40         Solitary                 2-5
# 2                 40       Herd-based                   1
# 3                 80      Group-based       2-4 (usually)
# 4                 56      Group-based               10-12
# ..               ...              ...                 ...
# 200               24      Group-based               10-50
# 201               25         Solitary                   1
# 202   Not Applicable         Solitary      Not Applicable
# 203               25      Group-based                5-20
# 204               20         Solitary            Up to 25
#
# [205 rows x 16 columns]

# %% [markdown]
# ### First we will reomve all upto values in columns where it is present

# %%
columns_with_upto=['Height (cm)','Weight (kg)','Lifespan (years)','Offspring per Birth']

# %%
#pd.DataFrame(df['Height (cm)'][df['Height (cm)'].str.match(regex)]) #example of upto

# %%
for x in columns_with_upto:
    regex='Up.*'
    df[x][df[x].str.match(regex)]=df[x][df[x].str.match(regex)].str.split(' ',expand=True)[2]

# %% [markdown]
# We need to change the datatype of numeric columns as every column type is string datatype.

# %%
df
# Out:
#                   Animal Height (cm) Weight (kg)             Color  \
# 0               Aardvark     105-130       40-65              Grey
# 1               Aardwolf       40-50        8-14      Yellow-brown
# 2       African Elephant     270-310   2700-6000              Grey
# 3           African Lion      80-110     120-250               Tan
# 4       African Wild Dog       75-80       18-36      Multicolored
# ..                   ...         ...         ...               ...
# 200                  Yak     140-160    500-1200      Brown, Black
# 201  Yellow-Eyed Penguin       60-65         1-3     Yellow, White
# 202            Yeti Crab          15         0.5      White, Hairy
# 203                Zebra     220-340     400-900      Black, White
# 204          Zebra Shark         330          32  Brown, Yellowish
#
#     Lifespan (years)         Diet               Habitat  \
# 0              20-30  Insectivore  Savannas, Grasslands
# 1              10-12  Insectivore  Grasslands, Savannas
# 2              60-70    Herbivore      Savannah, Forest
# 3              10-14    Carnivore  Grasslands, Savannas
# 4              10-12    Carnivore             Savannahs
# ..               ...          ...                   ...
# 200            20-25    Herbivore             Mountains
# 201               20    Carnivore         Coastal Areas
# 202               20     Omnivore    Hydrothermal Vents
# 203            20-25    Herbivore            Grasslands
# 204            25-30    Carnivore           Coral Reefs
#
#                  Predators Average Speed (km/h)              Countries Found  \
# 0            Lions, Hyenas                   40                       Africa
# 1          Lions, Leopards                24-30  Eastern and Southern Africa
# 2            Lions, Hyenas                   25                       Africa
# 3       Hyenas, Crocodiles                   58                       Africa
# 4            Lions, Hyenas                   56           Sub-Saharan Africa
# ..                     ...                  ...                          ...
# 200  Snow Leopards, Wolves                   24      Himalayas, Central Asia
# 201           Seals, Orcas                   25                  New Zealand
# 202         Not Applicable       Not Applicable                Pacific Ocean
# 203          Lions, Hyenas                   25                       Africa
# 204            Larger Fish                   20          Indo-Pacific region
#
#     Conservation Status           Family Gestation Period (days)  \
# 0         Least Concern  Orycteropodidae                 210-240
# 1         Least Concern        Hyaenidae                      90
# 2            Vulnerable     Elephantidae                 640-660
# 3            Vulnerable          Felidae                  98-105
# 4            Endangered          Canidae                      70
# ..                  ...              ...                     ...
# 200       Least Concern          Bovidae                 215-280
# 201          Endangered     Spheniscidae                   80-90
# 202       Not Evaluated         Kiwaidae          Not Applicable
# 203       Least Concern          Equidae                 180-365
# 204          Endangered  Stegostomatidae                   10-25
#
#     Top Speed (km/h) Social Structure Offspring per Birth
# 0                 40         Solitary                   1
# 1                 40         Solitary                 2-5
# 2                 40       Herd-based                   1
# 3                 80      Group-based       2-4 (usually)
# 4                 56      Group-based               10-12
# ..               ...              ...                 ...
# 200               24      Group-based               10-50
# 201               25         Solitary                   1
# 202   Not Applicable         Solitary      Not Applicable
# 203               25      Group-based                5-20
# 204               20         Solitary                  25
#
# [205 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Animal', 'Height (cm)', 'Weight (kg)', 'Color', 'Lifespan (years)',
#        'Diet', 'Habitat', 'Predators', 'Average Speed (km/h)',
#        'Countries Found', 'Conservation Status', 'Family',
#        'Gestation Period (days)', 'Top Speed (km/h)', 'Social Structure',
#        'Offspring per Birth'],
#       dtype='object')

# %%
for x in ['Height (cm)','Weight (kg)','Lifespan (years)','Average Speed (km/h)','Gestation Period (days)','Offspring per Birth','Top Speed (km/h)']:
    ab=df[x][df[x].str.contains('-')]
    df[x][df[x].str.contains('-')]=ab.str.split('-').str.get(-1)

# %%
df
# Out:
#                   Animal Height (cm) Weight (kg)             Color  \
# 0               Aardvark         130          65              Grey
# 1               Aardwolf          50          14      Yellow-brown
# 2       African Elephant         310        6000              Grey
# 3           African Lion         110         250               Tan
# 4       African Wild Dog          80          36      Multicolored
# ..                   ...         ...         ...               ...
# 200                  Yak         160        1200      Brown, Black
# 201  Yellow-Eyed Penguin          65           3     Yellow, White
# 202            Yeti Crab          15         0.5      White, Hairy
# 203                Zebra         340         900      Black, White
# 204          Zebra Shark         330          32  Brown, Yellowish
#
#     Lifespan (years)         Diet               Habitat  \
# 0                 30  Insectivore  Savannas, Grasslands
# 1                 12  Insectivore  Grasslands, Savannas
# 2                 70    Herbivore      Savannah, Forest
# 3                 14    Carnivore  Grasslands, Savannas
# 4                 12    Carnivore             Savannahs
# ..               ...          ...                   ...
# 200               25    Herbivore             Mountains
# 201               20    Carnivore         Coastal Areas
# 202               20     Omnivore    Hydrothermal Vents
# 203               25    Herbivore            Grasslands
# 204               30    Carnivore           Coral Reefs
#
#                  Predators Average Speed (km/h)              Countries Found  \
# 0            Lions, Hyenas                   40                       Africa
# 1          Lions, Leopards                   30  Eastern and Southern Africa
# 2            Lions, Hyenas                   25                       Africa
# 3       Hyenas, Crocodiles                   58                       Africa
# 4            Lions, Hyenas                   56           Sub-Saharan Africa
# ..                     ...                  ...                          ...
# 200  Snow Leopards, Wolves                   24      Himalayas, Central Asia
# 201           Seals, Orcas                   25                  New Zealand
# 202         Not Applicable       Not Applicable                Pacific Ocean
# 203          Lions, Hyenas                   25                       Africa
# 204            Larger Fish                   20          Indo-Pacific region
#
#     Conservation Status           Family Gestation Period (days)  \
# 0         Least Concern  Orycteropodidae                     240
# 1         Least Concern        Hyaenidae                      90
# 2            Vulnerable     Elephantidae                     660
# 3            Vulnerable          Felidae                     105
# 4            Endangered          Canidae                      70
# ..                  ...              ...                     ...
# 200       Least Concern          Bovidae                     280
# 201          Endangered     Spheniscidae                      90
# 202       Not Evaluated         Kiwaidae          Not Applicable
# 203       Least Concern          Equidae                     365
# 204          Endangered  Stegostomatidae                      25
#
#     Top Speed (km/h) Social Structure Offspring per Birth
# 0                 40         Solitary                   1
# 1                 40         Solitary                   5
# 2                 40       Herd-based                   1
# 3                 80      Group-based         4 (usually)
# 4                 56      Group-based                  12
# ..               ...              ...                 ...
# 200               24      Group-based                  50
# 201               25         Solitary                   1
# 202   Not Applicable         Solitary      Not Applicable
# 203               25      Group-based                  20
# 204               20         Solitary                  25
#
# [205 rows x 16 columns]

# %%
df['Offspring per Birth'][df['Offspring per Birth'].str.endswith('(usually)')]=3

# %%
df
# Out:
#                   Animal Height (cm) Weight (kg)             Color  \
# 0               Aardvark         130          65              Grey
# 1               Aardwolf          50          14      Yellow-brown
# 2       African Elephant         310        6000              Grey
# 3           African Lion         110         250               Tan
# 4       African Wild Dog          80          36      Multicolored
# ..                   ...         ...         ...               ...
# 200                  Yak         160        1200      Brown, Black
# 201  Yellow-Eyed Penguin          65           3     Yellow, White
# 202            Yeti Crab          15         0.5      White, Hairy
# 203                Zebra         340         900      Black, White
# 204          Zebra Shark         330          32  Brown, Yellowish
#
#     Lifespan (years)         Diet               Habitat  \
# 0                 30  Insectivore  Savannas, Grasslands
# 1                 12  Insectivore  Grasslands, Savannas
# 2                 70    Herbivore      Savannah, Forest
# 3                 14    Carnivore  Grasslands, Savannas
# 4                 12    Carnivore             Savannahs
# ..               ...          ...                   ...
# 200               25    Herbivore             Mountains
# 201               20    Carnivore         Coastal Areas
# 202               20     Omnivore    Hydrothermal Vents
# 203               25    Herbivore            Grasslands
# 204               30    Carnivore           Coral Reefs
#
#                  Predators Average Speed (km/h)              Countries Found  \
# 0            Lions, Hyenas                   40                       Africa
# 1          Lions, Leopards                   30  Eastern and Southern Africa
# 2            Lions, Hyenas                   25                       Africa
# 3       Hyenas, Crocodiles                   58                       Africa
# 4            Lions, Hyenas                   56           Sub-Saharan Africa
# ..                     ...                  ...                          ...
# 200  Snow Leopards, Wolves                   24      Himalayas, Central Asia
# 201           Seals, Orcas                   25                  New Zealand
# 202         Not Applicable       Not Applicable                Pacific Ocean
# 203          Lions, Hyenas                   25                       Africa
# 204            Larger Fish                   20          Indo-Pacific region
#
#     Conservation Status           Family Gestation Period (days)  \
# 0         Least Concern  Orycteropodidae                     240
# 1         Least Concern        Hyaenidae                      90
# 2            Vulnerable     Elephantidae                     660
# 3            Vulnerable          Felidae                     105
# 4            Endangered          Canidae                      70
# ..                  ...              ...                     ...
# 200       Least Concern          Bovidae                     280
# 201          Endangered     Spheniscidae                      90
# 202       Not Evaluated         Kiwaidae          Not Applicable
# 203       Least Concern          Equidae                     365
# 204          Endangered  Stegostomatidae                      25
#
#     Top Speed (km/h) Social Structure Offspring per Birth
# 0                 40         Solitary                   1
# 1                 40         Solitary                   5
# 2                 40       Herd-based                   1
# 3                 80      Group-based                   3
# 4                 56      Group-based                  12
# ..               ...              ...                 ...
# 200               24      Group-based                  50
# 201               25         Solitary                   1
# 202   Not Applicable         Solitary      Not Applicable
# 203               25      Group-based                  20
# 204               20         Solitary                  25
#
# [205 rows x 16 columns]

# %%
for x in ['Countries Found','Habitat','Predators']:
    # Split the 'Countries Found' column by commas into separate columns
    split_columns = df[x].str.split(', ', expand=True)

    # Rename the new columns with meaningful names (e.g., Country 1, Country 2)
    split_columns.columns = [f'{x} {i+1}' for i in range(split_columns.shape[1])]

    # Concatenate the split columns with the original DataFrame
    df = pd.concat([df, split_columns], axis=1)

    # Drop the original 'Countries Found' column
    df.drop(columns=[x], inplace=True)

# %%
df
# Out:
#                   Animal Height (cm) Weight (kg)             Color  \
# 0               Aardvark         130          65              Grey
# 1               Aardwolf          50          14      Yellow-brown
# 2       African Elephant         310        6000              Grey
# 3           African Lion         110         250               Tan
# 4       African Wild Dog          80          36      Multicolored
# ..                   ...         ...         ...               ...
# 200                  Yak         160        1200      Brown, Black
# 201  Yellow-Eyed Penguin          65           3     Yellow, White
# 202            Yeti Crab          15         0.5      White, Hairy
# 203                Zebra         340         900      Black, White
# 204          Zebra Shark         330          32  Brown, Yellowish
#
#     Lifespan (years)         Diet Average Speed (km/h) Conservation Status  \
# 0                 30  Insectivore                   40       Least Concern
# 1                 12  Insectivore                   30       Least Concern
# 2                 70    Herbivore                   25          Vulnerable
# 3                 14    Carnivore                   58          Vulnerable
# 4                 12    Carnivore                   56          Endangered
# ..               ...          ...                  ...                 ...
# 200               25    Herbivore                   24       Least Concern
# 201               20    Carnivore                   25          Endangered
# 202               20     Omnivore       Not Applicable       Not Evaluated
# 203               25    Herbivore                   25       Least Concern
# 204               30    Carnivore                   20          Endangered
#
#               Family Gestation Period (days)  ... Offspring per Birth  \
# 0    Orycteropodidae                     240  ...                   1
# 1          Hyaenidae                      90  ...                   5
# 2       Elephantidae                     660  ...                   1
# 3            Felidae                     105  ...                   3
# 4            Canidae                      70  ...                  12
# ..               ...                     ...  ...                 ...
# 200          Bovidae                     280  ...                  50
# 201     Spheniscidae                      90  ...                   1
# 202         Kiwaidae          Not Applicable  ...      Not Applicable
# 203          Equidae                     365  ...                  20
# 204  Stegostomatidae                      25  ...                  25
#
#                Countries Found 1 Countries Found 2 Countries Found 3  \
# 0                         Africa              None              None
# 1    Eastern and Southern Africa              None              None
# 2                         Africa              None              None
# 3                         Africa              None              None
# 4             Sub-Saharan Africa              None              None
# ..                           ...               ...               ...
# 200                    Himalayas      Central Asia              None
# 201                  New Zealand              None              None
# 202                Pacific Ocean              None              None
# 203                       Africa              None              None
# 204          Indo-Pacific region              None              None
#
#     Countries Found 4           Habitat 1   Habitat 2 Habitat 3  \
# 0                None            Savannas  Grasslands      None
# 1                None          Grasslands    Savannas      None
# 2                None            Savannah      Forest      None
# 3                None          Grasslands    Savannas      None
# 4                None           Savannahs        None      None
# ..                ...                 ...         ...       ...
# 200              None           Mountains        None      None
# 201              None       Coastal Areas        None      None
# 202              None  Hydrothermal Vents        None      None
# 203              None          Grasslands        None      None
# 204              None         Coral Reefs        None      None
#
#         Predators 1 Predators 2
# 0             Lions      Hyenas
# 1             Lions    Leopards
# 2             Lions      Hyenas
# 3            Hyenas  Crocodiles
# 4             Lions      Hyenas
# ..              ...         ...
# 200   Snow Leopards      Wolves
# 201           Seals       Orcas
# 202  Not Applicable        None
# 203           Lions      Hyenas
# 204     Larger Fish        None
#
# [205 rows x 22 columns]

# %%
df['Countries Found 4'].replace('None',np.nan,inplace=True)
df['Countries Found 3'].replace('None',np.nan,inplace=True)
df['Countries Found 2'].replace('None',np.nan,inplace=True)

# %%
print(df['Countries Found 4'].isna().sum(),df['Countries Found 3'].isna().sum(),df['Countries Found 2'].isna().sum())
# Out:
# 203 187 150

# %%
df.shape
# Out:
# (205, 22)

# %% [markdown]
# As we can see most of the countries columns - 'Country found 2','Country found 3,'Country found 4' have too many missing values thus dropping them.

# %%
df.drop(columns=['Countries Found 2','Countries Found 3','Countries Found 4'], inplace=True)

# %%
df = df.rename(columns={'Countries Found 1': 'Countries Found'})

# %%
df['Habitat 1'].replace('None',np.nan,inplace=True)
df['Habitat 2'].replace('None',np.nan,inplace=True)
df['Predators 1'].replace('None',np.nan,inplace=True)

df['Predators 2'].replace('None',np.nan,inplace=True)

# %%
print(df['Habitat 1'].isna().sum(),df['Habitat 2'].isna().sum(),df['Habitat 3'].isna().sum())
# Out:
# 0 121 204

# %%
print(df['Predators 1'].isna().sum(),df['Predators 2'].isna().sum())
# Out:
# 0 39

# %% [markdown]
# filling the same values in Habitat 2 from Habitat 1 where there is None.

# %%
df['Habitat 2'] = df['Habitat 2'].fillna(df['Habitat 1'])

# %% [markdown]
# Dropping Habitat 3 as it has lots of missing values which makes the column not usable

# %%
df.drop(columns=['Habitat 3'], inplace=True)

# %% [markdown]
# Filling the same values for predator 2 from predator 1 where there is no value

# %%
df['Predators 2'] = df['Predators 2'].fillna(df['Predators 1'])

# %%
df.shape
# Out:
# (205, 18)

# %%
df
# Out:
#                   Animal Height (cm) Weight (kg)             Color  \
# 0               Aardvark         130          65              Grey
# 1               Aardwolf          50          14      Yellow-brown
# 2       African Elephant         310        6000              Grey
# 3           African Lion         110         250               Tan
# 4       African Wild Dog          80          36      Multicolored
# ..                   ...         ...         ...               ...
# 200                  Yak         160        1200      Brown, Black
# 201  Yellow-Eyed Penguin          65           3     Yellow, White
# 202            Yeti Crab          15         0.5      White, Hairy
# 203                Zebra         340         900      Black, White
# 204          Zebra Shark         330          32  Brown, Yellowish
#
#     Lifespan (years)         Diet Average Speed (km/h) Conservation Status  \
# 0                 30  Insectivore                   40       Least Concern
# 1                 12  Insectivore                   30       Least Concern
# 2                 70    Herbivore                   25          Vulnerable
# 3                 14    Carnivore                   58          Vulnerable
# 4                 12    Carnivore                   56          Endangered
# ..               ...          ...                  ...                 ...
# 200               25    Herbivore                   24       Least Concern
# 201               20    Carnivore                   25          Endangered
# 202               20     Omnivore       Not Applicable       Not Evaluated
# 203               25    Herbivore                   25       Least Concern
# 204               30    Carnivore                   20          Endangered
#
#               Family Gestation Period (days) Top Speed (km/h)  \
# 0    Orycteropodidae                     240               40
# 1          Hyaenidae                      90               40
# 2       Elephantidae                     660               40
# 3            Felidae                     105               80
# 4            Canidae                      70               56
# ..               ...                     ...              ...
# 200          Bovidae                     280               24
# 201     Spheniscidae                      90               25
# 202         Kiwaidae          Not Applicable   Not Applicable
# 203          Equidae                     365               25
# 204  Stegostomatidae                      25               20
#
#     Social Structure Offspring per Birth              Countries Found  \
# 0           Solitary                   1                       Africa
# 1           Solitary                   5  Eastern and Southern Africa
# 2         Herd-based                   1                       Africa
# 3        Group-based                   3                       Africa
# 4        Group-based                  12           Sub-Saharan Africa
# ..               ...                 ...                          ...
# 200      Group-based                  50                    Himalayas
# 201         Solitary                   1                  New Zealand
# 202         Solitary      Not Applicable                Pacific Ocean
# 203      Group-based                  20                       Africa
# 204         Solitary                  25          Indo-Pacific region
#
#               Habitat 1           Habitat 2     Predators 1     Predators 2
# 0              Savannas          Grasslands           Lions          Hyenas
# 1            Grasslands            Savannas           Lions        Leopards
# 2              Savannah              Forest           Lions          Hyenas
# 3            Grasslands            Savannas          Hyenas      Crocodiles
# 4             Savannahs           Savannahs           Lions          Hyenas
# ..                  ...                 ...             ...             ...
# 200           Mountains           Mountains   Snow Leopards          Wolves
# 201       Coastal Areas       Coastal Areas           Seals           Orcas
# 202  Hydrothermal Vents  Hydrothermal Vents  Not Applicable  Not Applicable
# 203          Grasslands          Grasslands           Lions          Hyenas
# 204         Coral Reefs         Coral Reefs     Larger Fish     Larger Fish
#
# [205 rows x 18 columns]

# %% [markdown]
# work on missing values and NULLS

# %%
df.isna().sum()
# Out:
# Animal                     0
# Height (cm)                0
# Weight (kg)                0
# Color                      0
# Lifespan (years)           0
# Diet                       0
# Average Speed (km/h)       0
# Conservation Status        0
# Family                     0
# Gestation Period (days)    0
# Top Speed (km/h)           0
# Social Structure           0
# Offspring per Birth        0
# Countries Found            0
# Habitat 1                  0
# Habitat 2                  0
# Predators 1                0
# Predators 2                0
# dtype: int64

# %%
df.replace('Not Applicable',np.nan,inplace=True)

# %% [markdown]
# it is better to drop the data with missing values as replacing them with mean mode median values would not give accurate data for that animal.

# %%
df.dropna(inplace=True)

# %%
df[df['Height (cm)'].isna()]
# Out:
# Empty DataFrame
# Columns: [Animal, Height (cm), Weight (kg), Color, Lifespan (years), Diet, Average Speed (km/h), Conservation Status, Family, Gestation Period (days), Top Speed (km/h), Social Structure, Offspring per Birth, Countries Found, Habitat 1, Habitat 2, Predators 1, Predators 2]
# Index: []

# %%
df.dropna(subset=['Height (cm)'],inplace=True)

# %%
df.isna().sum()
# Out:
# Animal                     0
# Height (cm)                0
# Weight (kg)                0
# Color                      0
# Lifespan (years)           0
# Diet                       0
# Average Speed (km/h)       0
# Conservation Status        0
# Family                     0
# Gestation Period (days)    0
# Top Speed (km/h)           0
# Social Structure           0
# Offspring per Birth        0
# Countries Found            0
# Habitat 1                  0
# Habitat 2                  0
# Predators 1                0
# Predators 2                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# fixing special character values for each columns

# %%
df.isna().sum()
# Out:
# Animal                     0
# Height (cm)                0
# Weight (kg)                0
# Color                      0
# Lifespan (years)           0
# Diet                       0
# Average Speed (km/h)       0
# Conservation Status        0
# Family                     0
# Gestation Period (days)    0
# Top Speed (km/h)           0
# Social Structure           0
# Offspring per Birth        0
# Countries Found            0
# Habitat 1                  0
# Habitat 2                  0
# Predators 1                0
# Predators 2                0
# dtype: int64

# %%
df.loc[df['Height (cm)'] == '']
# Out:
# Empty DataFrame
# Columns: [Animal, Height (cm), Weight (kg), Color, Lifespan (years), Diet, Average Speed (km/h), Conservation Status, Family, Gestation Period (days), Top Speed (km/h), Social Structure, Offspring per Birth, Countries Found, Habitat 1, Habitat 2, Predators 1, Predators 2]
# Index: []

# %%
df.drop(df[df['Height (cm)'] == ''].index,inplace= True)

# %%
df.replace(',', '', regex=True,inplace=True)

# %%
df.replace('Varies',np.nan,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df['Lifespan (years)']=df['Lifespan (years)'].str.replace(r'\+', '', regex=True)

# %%
df['Average Speed (km/h)'][df['Average Speed (km/h)'].str.contains(r'.*water.*', regex=True)]=df['Average Speed (km/h)'][df['Average Speed (km/h)'].str.contains(r'.*water.*', regex=True)].str.split(" ",expand=True)[0]

# %%
df.replace(r'\(in burrow\)','',regex=True,inplace=True)

# %%
df['Gestation Period (days)'][df['Gestation Period (days)'].str.contains(r'.*days.*', regex=True)]='10'

# %%
df['Gestation Period (days)'][df['Gestation Period (days)'].str.contains(r'.*weeks.*', regex=True)]
# Out:
# 129    9 weeks
# Name: Gestation Period (days), dtype: object

# %%
df['Gestation Period (days)'][df['Gestation Period (days)'].str.contains(r'.*weeks.*', regex=True)]=f'{9 * 7}'

# %%
df['Gestation Period (days)'][df['Gestation Period (days)'].str.contains(r'.*months.*', regex=True)]
# Out:
# 23     42 months
# 32     12 months
# 37     12 months
# 54     14 months
# 81     18 months
# 103     8 months
# 121    16 months
# Name: Gestation Period (days), dtype: object

# %%
df['Gestation Period (days)'] = df['Gestation Period (days)'].apply(
    lambda x: f'{int(x.split()[0]) * 30}' if 'months' in x else x
)

# %%
df['Offspring per Birth']=df['Offspring per Birth'].str.replace(r')',"")

# %%
df['Offspring per Birth']=df['Offspring per Birth'].str.replace(r'Hundreds',"100")

# %%
# Initialize an empty list to store the non-convertible values
non_convertible_values = []

# Iterate through the column and attempt to convert to float
for value in df['Offspring per Birth']:
    try:
        float(value)
    except ValueError:
        non_convertible_values.append(value)

# Create a DataFrame containing the non-convertible values
df['Offspring per Birth'][df['Offspring per Birth'].isin(non_convertible_values)] = df['Offspring per Birth'][df['Offspring per Birth'].isin(non_convertible_values)].str.split(" ",expand=True)[0]

# %%
df.columns
# Out:
# Index(['Animal', 'Height (cm)', 'Weight (kg)', 'Color', 'Lifespan (years)',
#        'Diet', 'Average Speed (km/h)', 'Conservation Status', 'Family',
#        'Gestation Period (days)', 'Top Speed (km/h)', 'Social Structure',
#        'Offspring per Birth', 'Countries Found', 'Habitat 1', 'Habitat 2',
#        'Predators 1', 'Predators 2'],
#       dtype='object')

# %% [markdown]
# To correct the data types of different columns

# %%
float_columns = ['Height (cm)','Weight (kg)','Lifespan (years)','Average Speed (km/h)','Gestation Period (days)','Top Speed (km/h)','Offspring per Birth']
for x in float_columns:    
    df[x] = df[x].str.replace('[a-zA-Z]', '', regex=True)
    df[x] = df[x].astype(float)

# %%
df['Height-to-Weight Ratio'] = df['Height (cm)'] / df['Weight (kg)']

# %% [markdown]
# EDA Exploratory Data Analysis with Python

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 152 entries, 0 to 204
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Animal                   152 non-null    object
#  1   Height (cm)              152 non-null    float64
#  2   Weight (kg)              152 non-null    float64
#  3   Color                    152 non-null    object
#  4   Lifespan (years)         152 non-null    float64
#  5   Diet                     152 non-null    object
#  6   Average Speed (km/h)     152 non-null    float64
#  7   Conservation Status      152 non-null    object
#  8   Family                   152 non-null    object
#  9   Gestation Period (days)  152 non-null    float64
#  10  Top Speed (km/h)         152 non-null    float64
#  11  Social Structure         152 non-null    object
#  12  Offspring per Birth      150 non-null    float64
#  13  Countries Found          152 non-null    object
#  14  Habitat 1                152 non-null    object
#  15  Habitat 2                152 non-null    object
#  16  Predators 1              152 non-null    object
#  17  Predators 2              152 non-null    object
#  18  Height-to-Weight Ratio   152 non-null    float64
# dtypes: float64(8), object(11)
# memory usage: 23.8+ KB

# %%
pd.DataFrame(df.describe()).style\
    .set_properties(**{'background-color': 'lightyellow',
                      'color': 'black'})
# Out:
# <style type="text/css">
# #T_5285a_row0_col0, #T_5285a_row0_col1, #T_5285a_row0_col2, #T_5285a_row0_col3, #T_5285a_row0_col4, #T_5285a_row0_col5, #T_5285a_row0_col6, #T_5285a_row0_col7, #T_5285a_row1_col0, #T_5285a_row1_col1, #T_5285a_row1_col2, #T_5285a_row1_col3, #T_5285a_row1_col4, #T_5285a_row1_col5, #T_5285a_row1_col6, #T_5285a_row1_col7, #T_5285a_row2_col0, #T_5285a_row2_col1, #T_5285a_row2_col2, #T_5285a_row2_col3, #T_5285a_row2_col4, #T_5285a_row2_col5, #T_5285a_row2_col6, #T_5285a_row2_col7, #T_5285a_row3_col0, #T_5285a_row3_col1, #T_5285a_row3_col2, #T_5285a_row3_col3, #T_5285a_row3_col4, #T_5285a_row3_col5, #T_5285a_row3_col6, #T_5285a_row3_col7, #T_5285a_row4_col0, #T_5285a_row4_col1, #T_5285a_row4_col2, #T_5285a_row4_col3, #T_5285a_row4_col4, #T_5285a_row4_col5, #T_5285a_row4_col6, #T_5285a_row4_col7, #T_5285a_row5_col0, #T_5285a_row5_col1, #T_5285a_row5_col2, #T_5285a_row5_col3, #T_5285a_row5_col4, #T_5285a_row5_col5, #T_5285a_row5_col6, #T_5285a_row5_col7, #T_5285a_row6_col0, #T_5285a_row6_col1, #T_5285a_row6_col2, #T_5285a_row6_col3, #T_5285a_row6_col4, #T_5285a_row6_col5, #T_5285a_row6_col6, #T_5285a_row6_col7, #T_5285a_row7_col0, #T_5285a_row7_col1, #T_5285a_row7_col2, #T_5285a_row7_col3, #T_5285a_row7_col4, #T_5285a_row7_col5, #T_5285a_row7_col6, #T_5285a_row7_col7 {
#   background-color: lightyellow;
#   color: black;
# }
# </style>
# <table id="T_5285a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5285a_level0_col0" class="col_heading level0 col0" >Height (cm)</th>
#       <th id="T_5285a_level0_col1" class="col_heading level0 col1" >Weight (kg)</th>
#       <th id="T_5285a_level0_col2" class="col_heading level0 col2" >Lifespan (years)</th>
#       <th id="T_5285a_level0_col3" class="col_heading level0 col3" >Average Speed (km/h)</th>
#       <th id="T_5285a_level0_col4" class="col_heading level0 col4" >Gestation Period (days)</th>
#       <th id="T_5285a_level0_col5" class="col_heading level0 col5" >Top Speed (km/h)</th>
#       <th id="T_5285a_level0_col6" class="col_heading level0 col6" >Offspring per Birth</th>
#       <th id="T_5285a_level0_col7" class="col_heading level0 col7" >Height-to-Weight Ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5285a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5285a_row0_col0" class="data row0 col0" >152.000000</td>
#       <td id="T_5285a_row0_col1" class="data row0 col1" >152.000000</td>
#       <td id="T_5285a_row0_col2" class="data row0 col2" >152.000000</td>
#       <td id="T_5285a_row0_col3" class="data row0 col3" >152.000000</td>
#       <td id="T_5285a_row0_col4" class="data row0 col4" >152.000000</td>
#       <td id="T_5285a_row0_col5" class="data row0 col5" >152.000000</td>
#       <td id="T_5285a_row0_col6" class="data row0 col6" >150.000000</td>
#       <td id="T_5285a_row0_col7" class="data row0 col7" >152.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5285a_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_5285a_row1_col0" class="data row1 col0" >197.174342</td>
#       <td id="T_5285a_row1_col1" class="data row1 col1" >904.983684</td>
#       <td id="T_5285a_row1_col2" class="data row1 col2" >26.572368</td>
#       <td id="T_5285a_row1_col3" class="data row1 col3" >37.679868</td>
#       <td id="T_5285a_row1_col4" class="data row1 col4" >179.335526</td>
#       <td id="T_5285a_row1_col5" class="data row1 col5" >39.012105</td>
#       <td id="T_5285a_row1_col6" class="data row1 col6" >1428.120000</td>
#       <td id="T_5285a_row1_col7" class="data row1 col7" >13.191480</td>
#     </tr>
#     <tr>
#       <th id="T_5285a_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_5285a_row2_col0" class="data row2 col0" >390.641242</td>
#       <td id="T_5285a_row2_col1" class="data row2 col1" >5233.232423</td>
#       <td id="T_5285a_row2_col2" class="data row2 col2" >19.622801</td>
#       <td id="T_5285a_row2_col3" class="data row2 col3" >21.812222</td>
#       <td id="T_5285a_row2_col4" class="data row2 col4" >168.813230</td>
#       <td id="T_5285a_row2_col5" class="data row2 col5" >22.340857</td>
#       <td id="T_5285a_row2_col6" class="data row2 col6" >16342.907789</td>
#       <td id="T_5285a_row2_col7" class="data row2 col7" >33.413931</td>
#     </tr>
#     <tr>
#       <th id="T_5285a_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_5285a_row3_col0" class="data row3 col0" >5.000000</td>
#       <td id="T_5285a_row3_col1" class="data row3 col1" >0.050000</td>
#       <td id="T_5285a_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_5285a_row3_col3" class="data row3 col3" >0.240000</td>
#       <td id="T_5285a_row3_col4" class="data row3 col4" >10.000000</td>
#       <td id="T_5285a_row3_col5" class="data row3 col5" >0.240000</td>
#       <td id="T_5285a_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_5285a_row3_col7" class="data row3 col7" >0.033333</td>
#     </tr>
#     <tr>
#       <th id="T_5285a_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_5285a_row4_col0" class="data row4 col0" >53.750000</td>
#       <td id="T_5285a_row4_col1" class="data row4 col1" >6.000000</td>
#       <td id="T_5285a_row4_col2" class="data row4 col2" >15.000000</td>
#       <td id="T_5285a_row4_col3" class="data row4 col3" >24.000000</td>
#       <td id="T_5285a_row4_col4" class="data row4 col4" >60.000000</td>
#       <td id="T_5285a_row4_col5" class="data row4 col5" >24.000000</td>
#       <td id="T_5285a_row4_col6" class="data row4 col6" >1.000000</td>
#       <td id="T_5285a_row4_col7" class="data row4 col7" >0.647756</td>
#     </tr>
#     <tr>
#       <th id="T_5285a_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_5285a_row5_col0" class="data row5 col0" >90.500000</td>
#       <td id="T_5285a_row5_col1" class="data row5 col1" >55.500000</td>
#       <td id="T_5285a_row5_col2" class="data row5 col2" >20.000000</td>
#       <td id="T_5285a_row5_col3" class="data row5 col3" >38.500000</td>
#       <td id="T_5285a_row5_col4" class="data row5 col4" >138.000000</td>
#       <td id="T_5285a_row5_col5" class="data row5 col5" >40.000000</td>
#       <td id="T_5285a_row5_col6" class="data row5 col6" >1.500000</td>
#       <td id="T_5285a_row5_col7" class="data row5 col7" >2.119371</td>
#     </tr>
#     <tr>
#       <th id="T_5285a_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_5285a_row6_col0" class="data row6 col0" >180.000000</td>
#       <td id="T_5285a_row6_col1" class="data row6 col1" >312.500000</td>
#       <td id="T_5285a_row6_col2" class="data row6 col2" >30.000000</td>
#       <td id="T_5285a_row6_col3" class="data row6 col3" >55.000000</td>
#       <td id="T_5285a_row6_col4" class="data row6 col4" >260.000000</td>
#       <td id="T_5285a_row6_col5" class="data row6 col5" >56.000000</td>
#       <td id="T_5285a_row6_col6" class="data row6 col6" >6.000000</td>
#       <td id="T_5285a_row6_col7" class="data row6 col7" >10.434375</td>
#     </tr>
#     <tr>
#       <th id="T_5285a_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_5285a_row7_col0" class="data row7 col0" >3200.000000</td>
#       <td id="T_5285a_row7_col1" class="data row7 col1" >57000.000000</td>
#       <td id="T_5285a_row7_col2" class="data row7 col2" >150.000000</td>
#       <td id="T_5285a_row7_col3" class="data row7 col3" >120.000000</td>
#       <td id="T_5285a_row7_col4" class="data row7 col4" >1260.000000</td>
#       <td id="T_5285a_row7_col5" class="data row7 col5" >120.000000</td>
#       <td id="T_5285a_row7_col6" class="data row7 col6" >200000.000000</td>
#       <td id="T_5285a_row7_col7" class="data row7 col7" >250.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("The average height for the animals are {:.1f}cm, 99% of animals have top speed less than {:.2f}km/hr or less, while the maximum weight for an animal is {}kg.".format(df['Height (cm)'].mean(), df['Top Speed (km/h)'].quantile(0.99), df['Weight (kg)'].max()))
# Out:
# The average height for the animals are 197.2cm, 99% of animals have top speed less than 103.33km/hr or less, while the maximum weight for an animal is 57000.0kg.

# %%
print('99 % of animals have height less than {:.1f}cm'.format(df['Height (cm)'].quantile(0.99)))
# Out:
# 99 % of animals have height less than 2175.6cm

# %%
plt.figure(figsize=(15,10))
data = df.copy()
data=data[data['Height (cm)'] < data['Height (cm)'].quantile(0.90)]
sns.distplot(data['Height (cm)'].sort_values())
plt.title("Height distribution among the animals",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,10))
data2=df.copy()
data2=data2[data2['Weight (kg)'] < data2['Weight (kg)'].quantile(0.90)]
sns.distplot(df['Weight (kg)'].sort_values())
plt.title("Weight distribution among the animals",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['Height (cm)'], data['Weight (kg)'], c='blue', marker='o', label='Height vs. Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Scatter Plot of Height vs. Weight')
plt.legend()
plt.grid(True)
plt.show()

# %%
sns.jointplot(x="Conservation Status", y="Lifespan (years)", data=df, height=12, ratio=20, color="r")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16, 10))
df['Color'].value_counts().plot(kind='bar', color='skyblue')
plt.xlabel('Color')
plt.ylabel('Count')
plt.title('Distribution of Colors in Animals')
plt.xticks(rotation=40)
plt.show()

# %%
plt.subplot(1, 2, 2)
sns.boxplot(data=df, y='Lifespan (years)', color='lightgreen')
plt.ylabel('Lifespan (years)')
plt.title('Distribution of Lifespans (Box Plot)')

# Adjust the layout
plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 2, 2)
plt.hist(df['Lifespan (years)'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('Lifespan (years)')
plt.ylabel('Count')
plt.title('Distribution of Lifespans (Histogram)')
# Get the histogram counts and bin edges
counts, bin_edges, _ = plt.hist(df['Lifespan (years)'], bins=5)

# Annotate each bar with the count
for count, x in zip(counts, bin_edges):
    plt.text(x + 5, count + 1, str(int(count)), ha='center', va='bottom')

# %%
# Create a cross-tabulation of Color vs. Diet
color_diet = pd.crosstab(df['Color'], df['Diet'])

# Create a cross-tabulation of Color vs. Habitat
color_habitat = pd.crosstab(df['Color'], df['Habitat 1'])

# Set the figure size
plt.figure(figsize=(18, 6))

# Create a heatmap for Color vs. Diet
plt.subplot(1, 2, 1)
sns.heatmap(color_diet, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Color vs. Diet')

plt.tight_layout()

# %%
# Create a heatmap for Color vs. Habitat
plt.figure(figsize=(18, 6))
sns.heatmap(color_habitat, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Color vs. Habitat 1')
#plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Color vs. Habitat 1')

# %%
plt.figure(figsize=(20, 16))
df['Habitat 1'].value_counts().plot(kind='bar', color='skyblue')
plt.xlabel('Habitat 1')
plt.ylabel('Count')
plt.title('Distribution of Habitatsin Animals')
plt.xticks(rotation=45)
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(8, 6))

# Create a scatter plot to compare Average Speed vs. Top Speed
plt.scatter(df['Average Speed (km/h)'], df['Top Speed (km/h)'], c='blue', marker='o', label='Average Speed vs. Top Speed')
plt.xlabel('Average Speed (km/h)')
plt.ylabel('Top Speed (km/h)')
plt.title('Comparison of Average Speed vs. Top Speed')
plt.legend()

# Add a trendline
fit = np.polyfit(df['Average Speed (km/h)'], df['Top Speed (km/h)'], 1)
plt.plot(df['Average Speed (km/h)'], fit[0] * df['Average Speed (km/h)'] + fit[1], color='red')

# Show the plot
plt.show()

# %%
# Count the occurrences of each country
country_counts = df['Countries Found'].value_counts()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot to visualize the distribution of countries
country_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Distribution of Countries Where Animals are Found')
plt.show()

# %% [markdown]
# Animal Habitats

# %%
# Count the occurrences of each diet
country_counts = df['Diet'].value_counts()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot to visualize the distribution of Diet
country_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Diet')
plt.ylabel('Count')
plt.title('Distribution of diet count')
plt.show()

# %% [markdown]
# Carnivores=Omnivores=Herbivores

# %%
# Count the occurrences of each diet
country_counts = df['Conservation Status'].value_counts()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot to visualize the distribution of Diet
country_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Conservation Status')
plt.ylabel('Count')
plt.title('Distribution of Conservation Status')
plt.show()

# %% [markdown]
# The Urgency of Protecting endangered species from extinction

# %%
# Perform correlation analysis between Conservation Status and Average Speed
correlation = df['Conservation Status'].astype('category').cat.codes.corr(df['Average Speed (km/h)'])

# Create a bar plot to visualize the relationship
plt.figure(figsize=(13, 6))
sns.barplot(x='Conservation Status', y='Average Speed (km/h)', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %%
# Perform correlation analysis between Conservation Status and Height
correlation = df['Conservation Status'].astype('category').cat.codes.corr(df['Height (cm)'])

# Create a bar plot to visualize the relationship
plt.figure(figsize=(13, 6))
sns.barplot(x='Conservation Status', y='Height (cm)', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %%
# Perform correlation analysis between Conservation Status and Weight
correlation = df['Conservation Status'].astype('category').cat.codes.corr(df['Weight (kg)'])

# Create a bar plot to visualize the relationship
plt.figure(figsize=(13, 6))
sns.barplot(x='Conservation Status', y='Weight (kg)', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %% [markdown]
# Heaviest animals in the world

# %%
# Perform correlation analysis between Conservation Status and Weight
correlation = df['Conservation Status'].astype('category').cat.codes.corr(df['Height-to-Weight Ratio'])

# Create a bar plot to visualize the relationship
plt.figure(figsize=(13, 6))
sns.barplot(x='Conservation Status', y='Height-to-Weight Ratio', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.show()

# %%
pd.DataFrame(df.groupby('Family')[['Habitat 1', 'Diet']].agg(pd.Series.unique))
# Out:
#                                                         Habitat 1  \
# Family
# Accipitridae                               [Forests, Rainforests]
# Agamidae                            [Deserts, Northern Australia]
# Ailuridae                                   [Himalayan Foothills]
# Alcidae                           [North Atlantic, Coastal Areas]
# Ambystomatidae                                            [Lakes]
# ...                                                           ...
# Trochilidae                                            [Americas]
# Ursidae         [Forests, Temperate Broadleaf Forests, Arctic,...
# Varanidae                                               [Islands]
# Viverridae                                              [Forests]
# Vombatidae                                              [Forests]
#
#                                              Diet
# Family
# Accipitridae                          [Carnivore]
# Agamidae        [Omnivore, Insectivore Herbivore]
# Ailuridae                             [Herbivore]
# Alcidae          [Carnivore Piscivore, Carnivore]
# Ambystomatidae                        [Carnivore]
# ...                                           ...
# Trochilidae                      [Nectar Insects]
# Ursidae          [Omnivore, Herbivore, Carnivore]
# Varanidae                             [Carnivore]
# Viverridae                             [Omnivore]
# Vombatidae                            [Herbivore]
#
# [85 rows x 2 columns]

# %% [markdown]
# This table gives us an ideea of unique habitats and Diet for each family group

# %%
OffspringperBirth = df['Offspring per Birth'].value_counts()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar plot to visualize the distribution of Diet
OffspringperBirth.plot(kind='bar', color='skyblue')
plt.xlabel('Offspring per Birth')
plt.ylabel('Count')
plt.title('Distribution of most common offspring per birth count')
plt.show()

# %%
sns.jointplot(y="Gestation Period (days)", x="Social Structure", data=df, height=12, ratio=20, color="y")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Diet', y='Top Speed (km/h)', data=df)
plt.title('Interaction between Top Speed and Diet')
plt.xlabel('Diet')
plt.ylabel('Top Speed (km/h)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Diet', y='Lifespan (years)', data=df)
plt.title('Interaction between Top Speed and Lifespan (years)')
plt.xlabel('Diet')
plt.ylabel('Lifespan (years)')
plt.xticks(rotation=45)
plt.show()

# %%
numeric_cols = [x for x in df.columns if df[x].dtype in ['float64', 'int64']]
correlation_matrix = df[numeric_cols].corr()

# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
